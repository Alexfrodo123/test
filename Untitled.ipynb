# %%
import re
mac_address_table = open('Крутота.txt', encoding  = 'UTF-8').read()

slova = 'ростелеком'



pattern1 = r'\b[ростелкм]{1}\n'
pattern2 = r'\b[ростелкм]{2}\n'
pattern3 = r'\b[ростелкм]{3}\n'
pattern4 = r'\b[ростелкм]{4}\n'
pattern5 = r'\b[ростелкм]{5}\n'
pattern6 = r'\b[ростелкм]{6}\n'
pattern7 = r'\b[ростелкм]{7}\n'
pattern8 = r'\b[ростелкм]{8}\n'
pattern9 = r'\b[ростелкм]{9}\n'
pattern10 = r'\b[ростелкм]{10}\n'

prog1 = re.compile( pattern1 )
prog2 = re.compile( pattern2 )
prog3 = re.compile( pattern3 )
prog4 = re.compile( pattern4 )
prog5 = re.compile( pattern5 )
prog6 = re.compile( pattern6 )
prog7 = re.compile( pattern7 )
prog8 = re.compile( pattern8 )
prog9 = re.compile( pattern9 )
prog10 = re.compile( pattern10 )
  
result1 = prog1.findall(mac_address_table)
#print(result1)
  
result2 = prog2.findall(mac_address_table)
#print(result2)
  
result3 = prog3.findall(mac_address_table)
#print(result3)
  
result4 = prog4.findall(mac_address_table)
#print(result4)
  
result5 = prog5.findall(mac_address_table)
#print(result5)
  
result6 = prog6.findall(mac_address_table)
#print(result6)
  
result7 = prog7.findall(mac_address_table)
#print(result7)
  
result8 = prog8.findall(mac_address_table)
#print(result8)
  
result9 = prog9.findall(mac_address_table)
#print(result9)
  
result10 = prog10.findall(mac_address_table)
#print(result10)


result = result1 + result2 + result3 + result4 + result5 + result6 + result7 + result8 + result9 + result10
#print(result)

resultat = list(dict.fromkeys(result))
#print(resultat)

res = []
k = 0
r1 = 0
o1 = 0
c1 = 0
t1 = 0
e1 = 0
l1 = 0
k1 = 0
m1 = 0

for word in resultat:
    for simv in word:
        if simv == 'р':
            r1 = r1 + 1
            if r1 == 2:
                k = 1
        if simv == 'о':
            o1 = o1 +1
            if o1 == 3:
                k = 1
        if simv == 'с':
            c1 = c1 +1
            if c1 == 2:
                k = 1
        if simv == 'т':
            t1 = t1 +1
            if t1 == 2:
                k = 1
        if simv == 'е':
            e1 = e1 +1
            if o1 == 3:
                k = 1
        if simv == 'л':
            l1 = l1 +1
            if l1 == 2:
                k = 1
        if simv == 'к':
            k1 = k1 +1
            if o1 == 2:
                k = 1
        if simv == 'м':
            m1 = m1 +1
            if o1 == 2:
                k = 1
    if k == 0:
        res.append( word )
    k = 0
    r1 = 0
    o1 = 0
    c1 = 0
    t1 = 0
    e1 = 0
    l1 = 0
    k1 = 0
    m1 = 0     

        
#print('конечный результат', res) 

res2 = []

hjk = ''

for wor in res:
    for jk in wor:
        if jk != '\n':
            hjk = hjk + jk
    res2.append(hjk) 
    hjk = ''

stringRes = ', '.join( res2 )
print('Из слова ростелеком можно составить данные слова:', stringRes)
# Out:
# Из слова ростелеком можно составить данные слова: ер, ом, ост, кол, ком, кот, лек, лес, мел, мот, орс, орт, рол, ром, сет, сок, сом, сор, тол, том, кекс, клот, кокк, кокс, корм, корт, крем, крот, леер, лето, лоск, море, морс, мост, окот, осек, осот, рост, село, скол, скот, слом, сорт, срок, стек, сток, тело, торк, торс, трек, трок, трос, клок, кокор, кокос, колет, колос, креол, крест, леток, лотос, мелок, мелос, место, метол, молот, мотор, окрол, омлет, ореол, осмол, откол, откос, отсек, рокот, скорм, терем, тесло, торос, треск, клокот, колесо, комкор, корсет, кресло, крокет, лектор, метеор, омметр, осмотр, стекло, стокер, телекс, термос, ремесло, солемер, стрелок, селектор
